# %% [markdown]
# <a href="https://www.youtube.com/channel/UC80kXszNqAdWGTHFBcOKVdg"><img src="https://lh3.googleusercontent.com/3BGYLiEKEvFZ0u6eLcDbKvad__jwIRs30D19_ttfwuMv2TrJ3qovD_Lb_HGF4QvSCeVYoE2Ay6Hkfx0wN0LFV1VvILg7XIdrqR7bE9EtnbF2SwYIueV1-B33aomEwjTmkAKDY4TYopVfaSbfsBWzwfOXpoKy_ASFSrjKt_2p_E35fyTkTbES2t9GUnZ25bMjAe_Y4xqfkw-8lRqK9zCYVwlcD_e2YXUlNXs8ubJCHwZp3MAdPL3kWzLMnuVAKsiORvjt_IgCVINNcDAqfak56arvmtg4MXpcbyKSeYK2A33p0jcFnOkgddq3KhABVNqb0PRM7inpysBXMJ7-u7Q__Y4LVGdFh_gTmuPcxHQZXqS10kU_K86bOQtgqY5m9DjJ5Ixd--sxiR4evRr4LnjDH-9L-6Rcu4EZI6LXMxlANCuFGuTLgIIqrq6qgIliinjuxyuwsX-cl-pE_Y3TBcZ5dum52_O8HtkuPo3NOQXD0Pg4ZfQV11CSkeD-82HaONupDREROrrgFOriOYljzSj4438GSaK4IUTfDjP1UFMKnA6QuZGhSA0noStBSeIwTitSUsHbspxGwYm05Of9UiP-vpvhB5zGDUWl2gLpPsXxz6SDNlDGsVFekX81jNOrFnDzj-Me98FgK4AAmW4Of6Z8LN1ZjBw1MdFwGabLN94tHUMg0sPf-UJFbw5XqN0spoltuB8YmAGSyIWLHoC4eVuARcEX=w1659-h300-no?authuser=0" align="center"></a>
# # <center>Crawling Komentar Video Youtube</center>
# <hr>

# %% [markdown]
# **Tujuan** dari program ini adalah melakukan crawling (pengambilan) data komentar pada sebuah video Youtube menggunakan **Youtube Data API v3**. Sebelum mencoba program ini, pastikan Anda sudah memiliki (mengaktifkan) layanan Youtube Data API dan telah membangkitkan **API Key**.
#
# Jika belum memiliki **API KEY**, Anda dapat mengikuti petunjuk singkat sebagai berikut:
# 1. Login ke Google Developer Console (https://console.developers.google.com/)dengan akun Google Anda
# 2. Buat project baru dan lengkapi isian yang diminta.
# 3. Aktifkan Layanan API pada halaman project, dan cari **Youtube Data API v3**.
# 4. Dari halaman dashboard, buat kredential agar API tersebut dapat digunakan. Klik tombol **Buat Kredensial** (**Create Credential**). Lengkapi isian formnya.
# 5. Anda dapat mengakses / melihat API KEY pada tab **Credentials**.

# %% [markdown]
# #1. Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# #2. Fungsi untuk crawling komentar

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:

		# extracting required info
		# from each result object
		for item in video_response['items']:

			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])

			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:

					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']

					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %% [markdown]
# #3. Jalankan Proses Crawling

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyAJmotkRBrudmjtcstWDVQTRaWOWkHCIYk'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=5tucmKjOGi8
video_id = "alOOanmcVVc" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2024-03-27T14:51:00Z',
#   '@EkoPrasetyo-vm2my',
#   'Mo nnya knp krisna murti nya ga di undang jg ya? Kan biar lebih jelas',
#   0],
#  ['2024-03-26T14:57:39Z',
#   '@umihjnurra5809',
#   'Ya ungkap kembali keadilan tetep harus di tegakkan',
#   0],
#  ['2024-03-25T10:32:31Z',
#   '@Adrian123-uv9js',
#   'Butuh berapa lama reaksi racun bekerja pada tubuh seseorang hingga meninggal, dan berap lama jessica cs duduk di meja hidang,',
#   0],
#  ['2024-03-24T21:18:31Z',
#   '@dewabuana9128',
#   'Masyarakat ingin kasus jessica diungkap kembali demi keadilan hukum',
#   0],
#  ['2024-03-24T18:33:56Z',
#   '@helmybalweel782',
#   'Terlanjur bnyak yg akan JATUH jika kebenaran TERUNGKAP .. 😊<br><br>KAMI MENUNGGU KARMA😊😊<br><br>WE LOVE U CICI JES❤❤',
#   1],
#  ['2024-03-24T14:05:05Z',
#   '@freddyyudianto2027',
#   'Kompolnas tidak tahu HUKUM ? Sidang saja menyatkan tidak ada OTOPSI tapi kompolnas mengatakan  ada otopsi ? Kasus sudah 8 tahun loh.',
#   0],
#  ['2024-03-24T13:45:23Z',
#   '@freddyyudianto2027',
#   'Bagaimana gambar yang menampilkan gambar dari jauh (sudah di-zoom leibh kecil) tapi lebih buram dibanding yang tangan yang di-zoom lebih besar ?',
#   0],
#  ['2024-03-24T13:40:08Z',
#   '@freddyyudianto2027',
#   'GRASI ? gak bisa AMESTI ? Bagaimana pengadilan beleh men-vonis terdakwa membunuh dengan SIANIDA tapi tidak bisa membuktikan SEBAB KEMATIAN secara sah dan menyakinkan, yaitu tanpa otopsi dan dari 8 ahli toksikologi forensik ada 4 yang YAKIN SEBAB KEMATIAN bukan karena SIANIDA.',
#   0],
#  ['2024-03-24T13:35:31Z',
#   '@freddyyudianto2027',
#   'Edie bisa mendapatan dari ?',
#   0],
#  ['2024-03-24T13:28:42Z',
#   '@freddyyudianto2027',
#   'RS yang dipertanyakan kenapa sebelum di-zoom dilakukan penurunan resolusi ? Bukan masalah crop saja.',
#   0],
#  ['2024-03-22T17:47:33Z',
#   '@ahmadnasrullah9172',
#   'Pembawa acara bijaklah merangkai kata jaga perasaan netizen yg semakin kritis soal  kasus  jessica',
#   0],
#  ['2024-03-21T16:46:46Z',
#   '@harigemeng9773',
#   'Roy Suryo....pakar abal2, byk pengamatannya yg slh. Beda jauh kompetensinya ma abah apalagi ma bang Rismon',
#   0],
#  ['2024-03-21T02:06:33Z',
#   '@marthakobol9036',
#   'Knp Jessica di hukum sementara di cctv ada empat orang n tangan nya kosong',
#   0],
#  ['2024-03-21T01:49:52Z',
#   '@marthakobol9036',
#   'Kosong tangannya tak pegang apapa',
#   0],
#  ['2024-03-20T13:22:45Z',
#   '@RidwanWan-qn5cq',
#   'Assalamualaikum. Mohon pak presiden pak jokowi bebaskan jessica dia bukan pelakunya',
#   0],
#  ['2024-03-20T13:19:40Z',
#   '@RidwanWan-qn5cq',
#   'Jessica bukan pelakunya segera bebaskan jangan hanya debat suara-suara saja',
#   0],
#  ['2024-03-18T12:38:56Z',
#   '@user-fp5in2xp3b',
#   'Jangan dihargai hakim yg dalah',
#   0],
#  ['2024-03-18T06:34:11Z',
#   '@user-yr7ip9pl3v',
#   'Aku yakin di dalam kasus ini bayak korup, yang takut apabila kasus ini di bukak,,jelas di dalam badan mirna gak ada sianida kok masih bersalah,hukum apaan ini',
#   0],
#  ['2024-03-18T03:56:12Z',
#   '@aswahidkhan7158',
#   'sangat gak enak kalo roi panci jadi saksi ahli,   apa gak ada yg lain ... ?',
#   0],
#  ['2024-03-17T07:23:34Z',
#   '@AdiDi-qe9sh',
#   'Astaga Reza sampai di masukkan uang ke tasnya terkait kasus ini,siapa ya itu?',
#   0],
#  ['2024-03-17T07:07:58Z',
#   '@AdiDi-qe9sh',
#   'Roy Suryo dan dedi Hasibuan hanya mengira ngira, tanpa bukti yang jelas, dan terlau percaya dengan CVTV yang sudah direkayasa sedang DVAR kosong berarti ada manifulasi',
#   0],
#  ['2024-03-17T06:55:46Z',
#   '@AdiDi-qe9sh',
#   'Untuk mendapatkan gratifikasi bebas ke presiden Jesica Iskandar harus mengakuii bahwa dirinya salah. Ini memang berat buat Jessica Iskandar harus mengakuti kesalahan yang tidak pernah dilakukannya, namun daripada harus mendekam dipenjara selama 20 tahun. Lebih baik bagaimana',
#   0],
#  ['2024-03-17T06:26:59Z', '@user-cx4dc8uv4w', 'Apa dtnya apa jawaban 😅😅😅', 0],
#  ['2024-03-17T06:25:52Z', '@user-cx4dc8uv4w', 'Ini ni mulai, roi 😅😅😅', 0],
#  ['2024-03-17T02:39:41Z',
#   '@WelllemMaringka',
#   'saya   malas   dengarkan    roy   suryo,      tv  one   seperti    tidak   ada   narasumber    lain    yang   capable    saja',
#   1],
#  ['2024-03-16T21:06:31Z',
#   '@fery0282',
#   'roy suryo ngapa ngomong nyerocos gak karuan tapi omongannya itu gak punya nilai.',
#   0],
#  ['2024-03-16T15:58:50Z',
#   '@muhammadronaldsiagian9864',
#   '37 bukti rekayasa cctv dibongkar dan dikupas secara ilmiah kok sekarang manusia2 yg merasa ahli diam saja , roy suryo ahli segala ilmu pengetahuan terimah donk tantangan pak rismon S untuk debat ilmiah di media soal rekayasa dan manipulasi bukti pengadilan, jgn berani merendahkan dan menertawakan org yg ahli dibidang ke ilmuannya, statemen yg konyol dan meyesatkan masyarakat yg keluar dari mulut anda roy  !',
#   0],
#  ['2024-03-16T14:40:23Z',
#   '@bangtoyat1647',
#   'padahal intinya no otopsi no crime',
#   0],
#  ['2024-03-16T12:25:54Z',
#   '@AviChen-gx6no',
#   'Viral ga guna cuma buat carper kalo ga di usut tuntas,macam kerusuhan mei,siapa yg usut tuntas mei 98 🤣 keadilan?🤣🐂 shit 🤣',
#   0],
#  ['2024-03-15T20:53:33Z',
#   '@nurramdhan3091',
#   'Ini abi mayu baru orng yg benar pendapatnya...',
#   0],
#  ['2024-03-15T20:50:53Z',
#   '@nurramdhan3091',
#   'Roi suryo, klu ngak salah sdh kena kasus korupsi, bs di percaya ndak kesaksian nya akurat atau kesaksian nya karena uang? Perlu kita pertanyakan ini....',
#   0],
#  ['2024-03-15T17:25:45Z',
#   '@nonLatu',
#   'Mas Roy ,Logika beda dengan realita',
#   0],
#  ['2024-03-15T17:24:23Z',
#   '@user-fp5in2xp3b',
#   'Dapat bagian berapa pak ROI soryo ini',
#   0],
#  ['2024-03-15T17:16:31Z',
#   '@user-fp5in2xp3b',
#   'ROI soryo ini akan dapat karma dari jesica',
#   0],
#  ['2024-03-15T17:11:14Z',
#   '@user-fp5in2xp3b',
#   'Jangan dihargai pengadilan sesat ini',
#   0],
#  ['2024-03-15T13:49:41Z',
#   '@wasishadiwiratno',
#   'Semoga kak jessica kumala wongso di beri kesehatan panjang umur murah rezeki',
#   0],
#  ['2024-03-15T10:35:45Z',
#   '@srimuhayati4305',
#   'Dulu Rais soryo teriak teriak',
#   0],
#  ['2024-03-15T10:33:16Z',
#   '@srimuhayati4305',
#   'Jesica di korban Ken semua rakyat tau',
#   0],
#  ['2024-03-15T05:36:11Z', '@edensimarmata8083', 'Tuntaskan dengan baik', 0],
#  ['2024-03-15T05:11:05Z',
#   '@user-ht4zc7hv7u',
#   'Polisi ,jaksa,hakim dan para ahli,, semua mereka itu tamatan SD,lebih bagus kasus nya d ungkap lagi ama keluarga jesika atau pak oto hasibuan,,biar mereka2 yg nangani kasus nya apa lagi suami dan ayah nya mirna itu masuk buih,,,',
#   0],
#  ['2024-03-14T20:37:03Z',
#   '@tetinurhayati7477',
#   'Gilliran  c hani nekam di pnjara biar ngerasain .',
#   0],
#  ['2024-03-14T18:49:55Z',
#   '@muhammadolii8876',
#   'waktu akan membuktikan kwalitas seorang roy suryo',
#   0],
#  ['2024-03-14T14:11:56Z',
#   '@user-fp5in2xp3b',
#   'Apakah hakim tak pernah  salah nanti kena karma lo',
#   0],
#  ['2024-03-14T13:19:12Z',
#   '@user-fp5in2xp3b',
#   'ROI soryo na.nti kena karma dari jesica',
#   0],
#  ['2024-03-14T13:10:12Z',
#   '@user-fp5in2xp3b',
#   'ROI soryo akan mengganti jesica dipenjara karena karma dari jesica',
#   0],
#  ['2024-03-14T12:37:15Z',
#   '@SuryadiDiris-qs9pb',
#   'Sianida sebenarnya &quot;Doktrin&quot; yaitu bahan yang dibutuhkan untuk Festa dan dimasak oleh JPU kemudian diantar ke Ketua majelis selanjutnya dihidangkan untuk Jessika tapi tidak mati katanya Three Four zero.',
#   0],
#  ['2024-03-14T02:23:40Z',
#   '@tanjungsitanggang6246',
#   'Aneh... apa cafe oliver itu dibawah penguasaan jesica, sampai sampai CCTV nya tidak jelas gambarnya?',
#   0],
#  ['2024-03-12T23:45:08Z',
#   '@endangdewi5456',
#   'Klau betul2 jessica tdk bersala.bpk2 ini yg ngarang2 sehingga jessica sampai 7 thn di hukum. Tidak akan selamat se umur hidup nya..',
#   0],
#  ['2024-03-12T13:27:58Z',
#   '@ramahasan2744',
#   'Waduuuhhhhh ..prof .panci ..klo gk tau y g sebenarnya kejadian itu ..jgn sok tau prof.bodoh nyanyi lagu kebangsaan aja gk tau ..kok jd saksi ...dasar mulut comberan ....😂😢😮😅😊',
#   0],
#  ['2024-03-12T07:19:51Z',
#   '@mariamagdalena6846',
#   'Suryo merekayasa computer',
#   0],
#  ['2024-03-12T07:18:31Z',
#   '@mariamagdalena6846',
#   'R suryo byk bacot &amp; hoby fitnah',
#   0],
#  ['2024-03-12T06:22:35Z',
#   '@sydneysalvador5259',
#   'Harus di buka ulang…. Ada sesuatu yg Aneh  dalam sidang …. Barang bukti tak semua di dapat…. Buka kasus ini demi menjaga nama hukum di Indonesia ….',
#   0],
#  ['2024-03-11T14:51:53Z',
#   '@herlindadasril3268',
#   'Inilah beda hukum Barat yg mengacu pd delik (kesalahan yg disengaja atau tdk). Hukum Islam mengacu kepada Uzur (hal yg meringankan). <br><br>Dlm hukum Islam, lebih baik kita salah tidak menghukum org yg bersalah (Krn ada hukum akhirat yg siapapun tdk akan lolos dr hukuman), drpd kita salah menghukum org yg tdk bersalah.<br><br>Sbg contoh :<br>Mencuri dlm hukum barat, akan dicari delik, hal yg memberatkan.<br><br>Dlm hukum Islam, dicari uzur nya. Jika mencuri karena ada klga yg gak mkn, ada yg sakit. Ada warga negara yg terpaksa mencuri karena tdk ada uang, dlm hal ini, NEGARA YANG SALAH.',
#   1],
#  ['2024-03-10T16:47:39Z',
#   '@cimolgoreng877',
#   'skrg gmna udh 5 bulan ga ada kelanjutan',
#   0],
#  ['2024-03-10T13:11:11Z',
#   '@petanimudaindonesia3922',
#   'Pengen nendang muka Roy suryo',
#   1],
#  ['2024-03-09T14:54:14Z',
#   '@kenjikohlee3766',
#   'Bung Jonson anda kasihan sekali ya gak paham tentang forensik digital  ,,tapi anda masih lagi keras kepala padahal anda gak paham',
#   0],
#  ['2024-03-09T14:44:48Z',
#   '@kenjikohlee3766',
#   'BG Jonson anda ini keliru sekali ,, otopsi itu hak penyidik bukan keluarga ,,anda kok bisa muncul di TV dengan sedikit Ilmu pengetahuan otopsi ,,kasihan ya',
#   0],
#  ['2024-03-09T14:42:39Z',
#   '@kenjikohlee3766',
#   'Mantan kompolnas bicara punya fakta apa data ,anda bicara beberapa sebelum kejadian Jesica hadir di coffe olivier,anda kan cuman dengar dari prof Edy ..sedangkan prof Edy SDH meminta maaf atas pernyataan nya',
#   0],
#  ['2024-03-09T14:40:23Z',
#   '@kenjikohlee3766',
#   'Bung Roy CCTV yg kamu lihat itu jelas gak ,,, kamu kan bilang mungkin memindahkan Paper back ,, kasihan kamu ya bung Roy melihat CCTV yg SDH di rekayasa terus anda seperti org paling ahli',
#   0],
#  ['2024-03-09T10:28:39Z',
#   '@rutheredenharyo7355',
#   'Jessica tdk bisa berbohong LG sebab bahasa tubuhnya kelihatan dgn jelas meracuni Mirna......gatal 2 tangan nya garu2 kena racun yang keras Sianida..   patutlah terima hukuman mati.....dan pengacara yang gak jelas.  Katanya Rangga di bayar meracuni Mirna....dan balik lg mati bukan racun....😁',
#   0],
#  ['2024-03-09T10:02:21Z',
#   '@rutheredenharyo7355',
#   'Jessica tdk bisa berbohong LG sebab bahasa tubuhnya kelihatan dgn jelas meracuni Mirna..dgn jelas selalu menjauh dari korban....bukan Nya menolong...',
#   0],
#  ['2024-03-09T10:01:37Z',
#   '@user-er5ks6rx4n',
#   'Roy ...asli gimana <br>Semua itu editan ...kerjaan anak SD Roy pk aplikasi abal2<br>Lu gk ada apa2nya sama Rismon ..ente abal2. Ayo uji nyali sama Rismon jgn seolah olah ente ahli ... kan jelas hasilnya pengurangan pengurangan frame ..ente gak pinter.<br>Rismon menangani hal2 spt ini udah pengalaman 30 thn.<br>Diajak adu skill ngacir ... cobgor <a href="https://www.youtube.com/watch?v=alOOanmcVVc&amp;t=636">10:36</a>',
#   0],
#  ['2024-03-08T21:56:21Z',
#   '@jomisniper1823',
#   'Yg di pertanyakan ini org kompolnas kok aneh yah...',
#   0],
#  ['2024-03-07T16:11:49Z',
#   '@Kurniayshua',
#   'Presiden HARUS beri grasi atas kasus ini',
#   0],
#  ['2024-03-07T16:08:11Z',
#   '@Kurniayshua',
#   'roy suryo itu ahli yg gak berkualitas blasss, jd males liat video ini, bah.',
#   0],
#  ['2024-03-05T19:05:08Z',
#   '@apa-2boleh40',
#   'Undang2 di indonesia gak tegas. Kalau tegas pasti akan tahu penyebab kematian. Bolehkah sianida diletak semasa pengambilan sampel? Kalau boleh itu harus di selidik.',
#   0],
#  ['2024-03-04T16:55:55Z',
#   '@johnpaulqku',
#   'Direktur eksekutif kok ngomongnya ngawur ky anak SD',
#   0],
#  ['2024-03-03T10:03:51Z',
#   '@lycerisrico8943',
#   'Si Edi Kompolnas ini juga gokil 😂. Bukti blm jelas, CCTV gk jelas, otopsi gk sesuai SOP atau bisa dikatakan TIDAK DILAKUKAN, malah langsung kebelet loncat ke penangkapan.',
#   0],
#  ['2024-03-03T10:00:02Z',
#   '@lycerisrico8943',
#   'Saran juga buat si mbak host, kalo tanya jgn terkesan memojokkan, dan jgn memotong pembicaraan narasumber, malah terkesan tidak profesional',
#   0],
#  ['2024-03-03T09:34:38Z',
#   '@lycerisrico8943',
#   'Aduh, si Roy Suryo ini gelar ahli multimedia atau ahli spekulasi gerak-gerik. Gokil sebenernya liat pernyataan dia 😂. Yg ditanya &quot;apakah si J bener2 memasukkan sianida dan terlihat dari CCTV?&quot;, jawabannya muter2 ke spekulasi gerak-gerik si J. <br><br>Dari CCTV emang bener si J juga melakukan gerak-gerik (ya kali orang idup gk gerak), tapi masih gk jelas tuh dia memasukkan sianida ke kopi atau kgk. Gerakan2 tangan juga blm tentu dia menuangkan/memasukkan sesuatu.',
#   0],
#  ['2024-03-02T19:46:19Z',
#   '@user-vr3hr2yw2p',
#   'Tokong kalau mau diskusi itu, serius la, jangan seakan membuat kasus ini seperti kasus sepele. Ingat ada korban meninggal, dan ada yg di duga pelaku yg kita rasa janggal, untuk di jadikan pelaku kejahatan. Coba serius..',
#   0],
#  ['2024-03-02T19:39:55Z',
#   '@user-vr3hr2yw2p',
#   'Saya Kog jadi bingung ya lihat Roy Suryo ini,, kog penjelasan dia seakan memihak. Kasian jesica. Negara ini apakah harus santai saja,? Tolong beri kami kejelasan',
#   0],
#  ['2024-03-02T06:37:22Z',
#   '@agustinus2614',
#   'Mayatnya kenapa tdk di otopsi,ini  sdh kesalahan total untuk, mngetahui bahwa di dlm tubuh mirna ada racun.',
#   0],
#  ['2024-03-02T06:32:36Z',
#   '@paixinai4820',
#   'Ini tangan jg keluar bju tangan 3/4 ,sakan bju jesica bju tangan pendek coba teman perhatian vedio njd',
#   0],
#  ['2024-02-28T06:00:01Z',
#   '@achmadsuparman94',
#   'Bentar juga si roy suryo ikut ke tangkap . Hahahaha',
#   0],
#  ['2024-02-27T14:41:03Z',
#   '@user-jy4zm5fv4p',
#   'Roy suryo mau menguji pakai mata soal bukan asli menguji dengan basic keilmuan bidang cctv, jumlah cctv roy nebak 14, ahli odong2  berani bicara di publik dan cari muka aja ???',
#   0],
#  ['2024-02-23T16:42:36Z', '@suratmannyompa7032', 'Sok sok jg roi suria tu', 0],
#  ['2024-02-21T22:36:39Z',
#   '@user-zs6rh7eg5q',
#   'HUKUM DI NEGERI PRIDAPAN PARAAHHH TOTAL!!!!',
#   0],
#  ['2024-02-21T22:01:16Z',
#   '@user-zs6rh7eg5q',
#   'SAYA ORANG BODOH,TAPI NALURI SAYA MENGATAKAN SI KOMPOLNAS INI BICARA MENGARANG2 ..!!!DAN SI ROY KOPLOK INI JUGA MENG ADA2!!!😮😮😮',
#   0],
#  ['2024-02-19T18:49:24Z',
#   '@IlariskiRiski',
#   'Kasian bgt tu org gak salah di hukum 20thun',
#   1],
#  ['2024-02-19T15:38:23Z',
#   '@IwanDelviga',
#   'Roy suryo... Sok pinter... Atitude kurang.... Di atas lngit msih da langitt .. berasa lu doang yg ngerti .... 😅😅',
#   0],
#  ['2024-02-19T15:32:37Z',
#   '@IwanDelviga',
#   'Edi hasibuan bertele-tele ngomong nyee... Gaje nii orang<br><br>.',
#   0],
#  ['2024-02-19T15:27:46Z', '@IwanDelviga', 'Edi Hasibuan gaje ni orang...', 0],
#  ['2024-02-19T14:37:46Z',
#   '@lenimaharani6323',
#   'Cctv-nya sudah di rekayasa sudah di ganti sama orang &quot; yg dibayar uang yg sangat tebal kasihan hesika hadi kirban hanya merebut pangjat si Murti yg keji membuat cctv tapi belum bisa ahli otak bodoh hanta upah uang yg tebal',
#   0],
#  ['2024-02-19T15:33:34Z', '@IwanDelviga', 'Bz jadiii... 😅😅', 0],
#  ['2024-02-19T03:18:54Z',
#   '@user-nn6gv2wm8h',
#   '👍👍👍👍👍👍ahli semua.salam dari kebenaran.',
#   0],
#  ['2024-02-18T03:14:21Z',
#   '@jaduansonmunthe2256',
#   'Jika yg menghukum dan yg menyidik salah harus dihukum.masalah pk, harus dibuka bukan alasan karena ingkrah TDK bisa pk.rakyat menunggu pengadilan Jesika akan membuka peradilan kita seperti apa selama ini? Zaman sdh berobah harus diungkap kasus ini kembali.dan jika benar hakim dan jaksa juga penyidik salah, mereka pantas dihukum berat',
#   0],
#  ['2024-02-17T13:34:33Z',
#   '@user-vq4jm9fl5e',
#   'Kita.hrs.semuwa.berjuwang.kalawu.tidak..anak.anak.cucu.yg.akan.kena.dgn.kejaliman..penguwasa.kasus.ini.tidak.bisa.kita.biyarkan.ayo..ayo..kita.sama.sama',
#   0],
#  ['2024-02-16T12:30:08Z',
#   '@MattaLunggak88',
#   'Seharusnya media di seluruh Indonesia, bisa mengkawal terus masalah sianida ini, kasihan Jessica, kasusnya selalu jadi misteri, mungkin karna di Indonesia ini, kebanyakan nonton film drama x ya, sehingga hukum pun bisa di buat drama senetron 🤔🤔🤔',
#   0],
#  ['2024-02-16T04:48:02Z',
#   '@benniss756',
#   'Tengok jam di tangan pun salah 😂',
#   0],
#  ['2024-02-15T15:44:36Z',
#   '@dwicaem3486',
#   'Semngat Persatuan Apokat Indnesia.&quot; Tegakan Hukum yg Tidak bersalah.💪💪💪💪🙏🙏🙏',
#   0],
#  ['2024-02-15T09:42:51Z',
#   '@user-hz3vx1cm4o',
#   'Roy Suryo gagal paham, video  yg ditampilkan merupakan video yg telah direkayasa, zoom in memang bukan rekayasa, gak nyangka Roy Suryo sebodoh itu',
#   0],
#  ['2024-02-14T23:44:11Z',
#   '@iketutnerkha3490',
#   'Orang ingin tahu yang sebenarnya, bukan saling ngotot. Jadi sesuai prosedur hukum, dan bila ada yang tak sesuai dengan prosedur hukum, ada apa? Dan itu perlu dipertanyakan, dan patut dicurigai, ada apa, siapa orangnya?',
#   0],
#  ['2024-02-14T12:16:18Z',
#   '@EmanEman-jb2mj',
#   'seret semua yg terl8bat jgn lihat pangkat dan jabatan    penjarakan klo benar hukum itu merata berlaku untuk warga negara.....',
#   1],
#  ['2024-02-14T03:54:40Z',
#   '@ArdyFath-dx3lw',
#   'Usut terus jangan bikin malu dimata dunia',
#   0],
#  ['2024-02-13T13:27:15Z',
#   '@dianabutiq2566',
#   'Muka panci grombolan mafia hukum.. 🤣🤣🤣',
#   1],
#  ['2024-02-13T05:42:20Z',
#   '@dewantaradewantara4237',
#   'Si edi ngomong&#39;y muter2 trs nyari org bingung gk bisa jwb edi edi bnr2 gk ndoLor',
#   0],
#  ['2024-02-13T05:32:09Z',
#   '@user-gm3be1sd8y',
#   'Ini orang kebanyakan politik .indonesia ini ploitik dipermainkan oleh hukum .sdh sangat jelas dan sangat terang bahwa jesika itu tdk bersalah .yg bersalah itu para polisi dan penjahat dikejaksaan karna duet (uang) hanya allah yv akan membalas .sambo contoh allah akan dgn mudah membalasnya',
#   0],
#  ['2024-02-13T05:06:28Z',
#   '@dewantaradewantara4237',
#   'KompoLnas gk nodoLor',
#   0],
#  ['2024-02-13T04:43:23Z',
#   '@dewantaradewantara4237',
#   'Apa ampLop roy suryo t&#39;kesan m&#39;protek org2 di bayar oLeh edi darmawan',
#   0],
#  ['2024-02-13T04:40:12Z',
#   '@dewantaradewantara4237',
#   'MuLaiLah dari pemiLik cafe oLivier &amp; pegawai&#39;y stLh itu periksaLah org2 meLindungi reka yasa cctv. Krisna murty &amp; yg ambo. Juga yg mereka yasa cctv&#39;y BaruLah 3 jpu Licik &amp; hakim hakim sesat prof eddy hiariej',
#   0],
#  ['2024-02-12T17:46:47Z',
#   '@reaksiviral9910',
#   'Siroy.  Berdasarkan asumsi ..curiga .. padahal menghukum orang harus BUKTI KONGKRIT /PASTI BUKAN BERDASARKAN ASUMSI DAN CURIGA .  BISA SAJA JESSICA MENYUSUN UTK MEMBUAT MEJA LUAS DAN MAKANYA  DISUSUN DI PINGGIRAN MEJA SAJA DAN DIPINDAH KE KURSI SETELAH ITU KARENA MASIH TERASA SEMPIT MEJA TSB .. INI JUGA ASUMSI DAN BISA DIJADIKAN BAHAN BUKTI,  ini kasus besar bagaimana bisa tidak jalankan autopsi apalagi harus smp memenjarakan org yg tidak pasti kesalahannya.',
#   0],
#  ['2024-02-12T11:03:22Z',
#   '@user-ur6wh7lm2h',
#   'Memindakan  peiper bek tdk memasuk kok di bilang di sangka  memasukkan',
#   0],
#  ['2024-02-12T10:56:53Z',
#   '@user-ur6wh7lm2h',
#   'Kalau netisen sarankan polri tangkap roi panci supaya bangsa ini terbebar dari gadu....',
#   0],
#  ['2024-02-12T10:53:04Z',
#   '@user-ur6wh7lm2h',
#   'La roi panci panci, pintar dan piawai ngibul, nipu rekayasa, akal-akalan',
#   0],
#  ['2024-02-12T10:47:01Z',
#   '@user-ur6wh7lm2h',
#   'Coba kalian lihat dan dengar omongan nya selalu mendua hati, muda-mudahan atau insia aulla, itu bukan fakta',
#   0],
#  ['2024-02-12T10:43:20Z',
#   '@user-ur6wh7lm2h',
#   'Kenapa semua presenter selalu sesat dalam bertutur bela kesesatan. Semua presenter bahkan semua  nara sumber seslalu memberi pengakuan menghargai ponis hakim walaupun sesat. Baik omong kosong roi panci ahli abal-abal, edy yg katanya prof pembohong,  yang kesemuanya omong kosong',
#   0],
#  ['2024-02-12T05:12:50Z',
#   '@ateckenginering-hc2qv',
#   'Roisuryo tidak laku di politik sekarang ikutan di hakum dasarnya iblis kemana juga pasti iblis',
#   0],
#  ['2024-02-12T04:11:13Z',
#   '@gintamauli',
#   'Ini bukan hanya masalah jesika, jika seperti ini dibiarkan maka berapa banyak org2 selanjutnya yg akan pejabat, pemegang kuasa lumpuhkan tanpa keadilan',
#   0],
#  ['2024-02-12T04:09:19Z',
#   '@gintamauli',
#   'Klo nonton ini, smua masyarakat Indonesia bisa melihat bobrok dan hancurnya Indonesia di tangan org2 yg tdk menegakkan prosedur dan keadilan dgn baik. Ingat smua ada akhirnya jika ada manusia yg tdk di manusiakan oleh yg tdk manusiawi maka akhirnya Tuhan yg akan memberikan pengertian. Karma itu ada dn pasti akan terjadi.',
#   0],
#  ['2024-02-12T02:33:17Z',
#   '@user-ee8oz9vl9g',
#   'Kasus jesica.. Saya yakin jesica tak bersalah.. Logika madak mau ngracun orang di depan umum...',
#   0],
#  ['2024-02-11T19:07:22Z',
#   '@theopilus4579',
#   'Mari kita dukung kasus ini dibuka kembali.. dengan petisi ke presiden diakhir jabatannya.',
#   0],
#  ['2024-02-11T16:47:40Z',
#   '@siussiusbali1669',
#   'Skak mat dia itu pembohong,dktr tjaya aja sudah melakukan pemeriksaan,😅😅😅',
#   0],
#  ['2024-02-11T16:45:01Z',
#   '@siussiusbali1669',
#   'Otopsi bang yg bisa ungkapkan  kasus',
#   0],
#  ['2024-02-11T16:41:25Z',
#   '@siussiusbali1669',
#   'Berarti mereka hanya menduga,ada apa pergerakan jesika,hahh tidak terlalu pasti,namanya pembunuhan berancana katanya,pasti banyak di persiapkan termasuk menyaksikan kejadian mirna,tanda tanya siapa yang bawa oesanan itu,kenapa tidak di curigai pengantar kopi,karna hanya di sana bisa jelaskan sianida berada,,',
#   0],
#  ['2024-02-10T23:04:47Z',
#   '@delisaaqila4869',
#   'Mirisnya presidenpun bungkam soal hukum.',
#   0],
#  ['2024-02-10T12:58:31Z',
#   '@wiwidwiwid8005',
#   'Semoga Bapak Presiden Joko Widodo tergugah hatinya utk membuka lagi kasus yg menimpa Jessica,agar Kebenaran yg Hakiki bs terungkap',
#   0],
#  ['2024-02-10T12:09:34Z',
#   '@MohAmin-dz7qb',
#   'Tolong para penegak hukum jangan dipemainkan',
#   0],
#  ['2024-02-10T03:49:53Z',
#   '@opiehhioda1650',
#   'Biarin dulu apa klo orang lgi jelasin biar kelar dulu... host nya potongin orang lgi jelasin mulu... biarin dulu biar kelar jelasin biar jelas jangan di potongin mulu hostnya diem perhatiin dulu... tuh yg cewe hostnya jgn sok tau diem dulu dengerin orang jelasin jangan di potong mulu',
#   0],
#  ['2024-02-09T14:46:31Z',
#   '@kucingkucingcute',
#   'yang jadi masalah pejabat pejabat kenapa diam aja ya melihat ini. kalau lihat rekaman cctv yang burem gitu, orang ga tau apa apa juga tau kalau itu udah diedit',
#   0],
#  ['2024-02-09T11:44:41Z', '@NickiYanto-wx1vd', 'Bpk baju batik bagus', 0],
#  ['2024-02-08T21:16:19Z',
#   '@arkalanang5825',
#   'Bila tidak bisa diadili dengan benar&quot; (tidak sesat).maka baiknya di Adilli dengan Hukum Rimba.',
#   0],
#  ['2024-02-08T13:14:45Z',
#   '@surunudinsurunudin9247',
#   'SEMUA ORG INI ,  HANYA SANDIWARA MEMPWRMAINKAN HUKUM , HUKUM DI PRODUKSI SEBAGAI DAGELAN DAN KEDHOLIMAN , INI SEMUA ORG SDH IKUT ANDIL BERDOSA LHO...IKUT MAKAN DUIT ATAU MENUTUP2 I KEBENARAN.<br>YG BENAR DI SALAHKAN YG SALAH DI BENARKAN.<br>SEPERTI PEMILU 2024 PRABOWO KALAH TAPI DI MENANGKAN, ANIS MENANG DI REKAYASA DI KALAHKAN.<br>OK.. KESALAHAN.',
#   0],
#  ['2024-02-08T07:48:44Z',
#   '@paulusperbakinsragen3116',
#   'Kasian Jesica di korbankan untuk menaikkan popularitas Krisna Mukti dan Sambo, padahal tidak ada bukti klo dia yg memberikan racun sianida kepada sahabatnya',
#   0],
#  ['2024-02-07T17:10:54Z',
#   '@sukowiyono6090',
#   'Semoga jesika bisa dibebaskan dr penjara Alliiah tidak tidur',
#   0],
#  ['2024-02-07T14:31:17Z',
#   '@nanihhariyati957',
#   'Roy suryo klw sy lihat tdk fer, ada keberpihakan bukan cari kebenaran, seolah memojokan jesika',
#   0],
#  ['2024-02-07T11:24:50Z',
#   '@user-be4jv3kf1l',
#   'Ngak percaya Ama hukum di indonesia.sambo aja bisa pk yg jelas jadi dalang nya',
#   0],
#  ['2024-02-07T09:02:29Z',
#   '@rossidinzaenur',
#   'Saya jadi teringat, ketika saya di tuduh,  padahal saya tidak pernah melakukan nya. Malah saya di ancam. Di Suruh ngaku  padahal saya tidak pernah melakukan.',
#   0],
#  ['2024-02-07T05:06:55Z',
#   '@user-yq2tv5xe5k',
#   'Ayo tuntaskan,siapa dalang semua peristiwa ini.apa benar krisnamurti adalah aktor dibalik peristiwa ini',
#   0],
#  ['2024-02-06T20:23:25Z',
#   '@alkuzrah6836',
#   'Edi ini bukan org pintar,kok bisa manusia ini di undang di acara besar seperti ini,sama aja dgn Roy,suka mencari pencitraan tapi pikiran dan analisa mereka bodoh semua',
#   0],
#  ['2024-02-06T16:42:53Z',
#   '@user-gp1gs7lg1t',
#   'Kasus jesika kopi sianida hrs di buka kembali.<br>Seluru pakar hukum hrs bersatu utk membuka kembali keadilan bg jesika<br>Sbg manusia jrs jujur dan mau menolong org yg teraniaya.<br>Seorg yg tdk bersalah di rekayasa oleh org yg berduit utk menjadikan jesika sbg tersangka dan tanpa bukti yg benar.<br>Tuhan akan mengutuk org2 yg berhati jahat pd Jesika.',
#   0],
#  ['2024-02-06T13:49:24Z',
#   '@SubaliGumawang-im4zj',
#   'Mohon pak oto kasusnya hrs dibuka kembali, siapa yg salah dan yg benar perlu pembuktian',
#   0],
#  ['2024-02-06T12:16:57Z',
#   '@slametagung240',
#   'Roy panci tu vs bang rismon ibarat panci SDN kls 6 , bang rismon Uda S3',
#   0],
#  ['2024-02-06T12:03:54Z',
#   '@zamricansaw7820',
#   'Hai rok suryo kau tau tidak tangan jesika pakai jam tangan  sedang tangan dividio itu tidak pakai jam, apa mata kau buta rok suryo, binatang kau rok suryo',
#   0],
#  ['2024-02-06T02:57:10Z',
#   '@sriyantosriyanto-xj4th',
#   'harus dibuka ulang biar jelas banar atau salah si anida itu, kalo si anida tidak bersalah ya semua yang terlibat harus diadili',
#   0],
#  ['2024-02-05T17:37:39Z',
#   '@darlingdarling2386',
#   'Bagus pa buka kembali kasus sianida',
#   0],
#  ['2024-02-05T15:46:05Z',
#   '@user-gb4fb6vl6x',
#   'Dipnjara  bgitu lm  ksalahn  blum jls    jesika  blum tnntu  brsalh kynya',
#   0],
#  ['2024-02-05T03:41:37Z',
#   '@habibali1509',
#   'Ayo pak jokowi bantu buka kembali kasus jessica biar ketangkap pembunuh sebenarnya',
#   0],
#  ['2024-02-04T15:39:07Z',
#   '@user-ms9uu2pu2w',
#   'Soalnya di daerah saya ada Lo yang habis minum meninggal',
#   0],
#  ['2024-02-04T15:37:21Z',
#   '@user-ms9uu2pu2w',
#   'Apa lagi ccti bisa di setting guys',
#   0],
#  ['2024-02-04T15:36:38Z', '@user-ms9uu2pu2w', 'Hati hati banyak rekayasa', 0],
#  ['2024-02-04T15:04:13Z',
#   '@ozaybewok5617',
#   'Ungkap jangan lama lama dong kasus ini.....😢 Jesica tidak salah .geser geser kantong bawaan jesica mungkin mejanya sempit',
#   0],
#  ['2024-02-04T15:01:39Z',
#   '@ozaybewok5617',
#   'Gak nyambung nih adinda edi...',
#   0],
#  ['2024-02-04T11:52:42Z', '@ayahbunda1185', 'Roy banyak bacot', 0],
#  ['2024-02-04T11:49:05Z', '@ayahbunda1185', 'Roy sok', 0],
#  ['2024-02-04T10:22:38Z',
#   '@user-ur6wh7lm2h',
#   'Itu hanya bayang-bayang hantu, tidak bisa di liat mana racun dan nyata di masukkan  ke gelas...jadi ROI panci hanya menduga+duga...',
#   0],
#  ['2024-02-04T04:11:02Z',
#   '@user-ux3tm5jx8f',
#   'Ini lh hukum di negri ini,,,sangat2 bobrok,,,,dari kepolisian smpai ke hakim jaksa nya sbgian bnyak yg demi uang,,,rela melakukan hal yg bertentangan,,',
#   0],
#  ['2024-02-03T16:31:06Z',
#   '@user-jb3cq9ln2q',
#   'Aku takun klau tak terungkap pasti akan menjadi hal biasa besok2nya',
#   0],
#  ['2024-02-03T11:55:29Z', '@user-sb8qr7qo6b', 'dr jaja logika .bicaranya', 0],
#  ['2024-02-03T00:58:28Z', '@NurhayatiMustafa-ds2jx', 'Ngak karuan karuan', 0],
#  ['2024-02-02T18:58:43Z',
#   '@user-mo9fl3tl1b',
#   'Memang banyak kejanggalan dlm kasus yesika, sebaiknya perkaranya dibuka kembali.',
#   0],
#  ['2024-02-02T16:55:27Z', '@sulaursula7007', 'bongkarrrrr terusss', 0],
#  ['2024-02-01T19:43:36Z',
#   '@kasitotromol6847',
#   'Ayo teman netizen seindonesia bantu jesica dg doa insya allah bisa tuntas permasalahan ini',
#   0],
#  ['2024-02-01T13:39:41Z',
#   '@BarangsanoFlortje-di9xp',
#   'Bukti rekayasa pun yg di jadikan sebagai alat bukti sah ?  Apa kah bukti hasil rekayasa pun di akui sah ?😂😂',
#   0],
#  ['2024-02-01T12:36:19Z',
#   '@user-fs7ld7zs5u',
#   'SemogaTuhan menunjukan kebesarannya yg tdk bersalah harus dibela dan dibebaskan',
#   0],
#  ['2024-02-01T06:40:54Z',
#   '@user-oc9zq2nv5e',
#   'Lanjut om Otto,, lanjutkan om otto',
#   0],
#  ['2024-01-31T14:07:29Z',
#   '@rinaladitya3225',
#   'Sgt setju sepertiya ad kegjlan.dlm ksus in',
#   0],
#  ['2024-01-31T13:18:03Z',
#   '@doubleprinseslinebosejagok6631',
#   'Smg sehat slalu mbk, kebenaran ada d pihak benar, 🙏',
#   0],
#  ['2024-01-31T06:24:29Z',
#   '@dedenmulyana9289',
#   'Salah jangan ga kalou menghargai keputusan yang salah 😂😂😂',
#   0],
#  ['2024-01-31T03:48:14Z', '@amanda_2721', 'Roy panci menjijikan.', 0],
#  ['2024-01-31T02:47:33Z',
#   '@user-zh9bn5pg7h',
#   'Udah bodo sok pintar kau roi ,dan tak tau malu . Kau trima aja karma nya',
#   0],
#  ['2024-01-30T23:33:54Z', '@asnahhutapea9125', 'Mungkin,,,', 0],
#  ['2024-01-30T16:42:35Z',
#   '@ChristinaDesembrina',
#   'Izin tanya pak kompolnas bagaimana cctv itu sudah di turunkan resolusi dari asli nya  yang terang menjadi kabur  seperti tindakan bapak tadi sendiri juga menjelaskan Jesica aja di mana apakah bukti ini masih sah di hadirkan ke pengadilan ??? Cctv-nya sudah di edit  resolusi sudah di turunkan menjadi kabur / tidak jelas penggerakan nya Mohon di Jawabannya  kepada masyarakat???',
#   0],
#  ['2024-01-30T15:34:04Z',
#   '@yokoosableung5318',
#   'Barang siapa melakukan hukuman kepada orang yg tak bersalah celakalah orang itu, harus bertanggung jawab di hari twrakhir',
#   0],
#  ['2024-01-30T15:30:51Z',
#   '@yokoosableung5318',
#   'Udah, di hifnutis saja siapa yg melakukan,',
#   0],
#  ['2024-01-30T06:37:11Z',
#   '@user-qt9ck9rq4t',
#   'Menurut sy Jesica tdk bersalah, Jesica bukan pelaku , Krn mudah sekali menentukan pelaku kalo dg cara sperti itu, mana mungkin jesika terang2an sperti itu, itu sih namanya bunuh diri , Jd tidak mungkin... Pasti ada org lain yg seolah2 Jesica lah yg membunuh',
#   0],
#  ['2024-01-30T04:12:20Z', '@user-gk5jb8kk2t', 'Memang SDH berantakan.', 0],
#  ['2024-01-30T03:23:58Z',
#   '@user-gk5jb8kk2t',
#   'Ada jg TDK berkwalitas jg jadi analys',
#   0],
#  ['2024-01-30T01:48:37Z',
#   '@cahayadwiaprilia1404',
#   'Seandainya yg bersangkutan oknum jaksa,hakim penyidik merasa benar,pasti sudah angkat bicara,tapi kenyataanya pada diam semua.kalau gak mengklarifikasi pada nitizen,hukum Allah yg bicara.diganjar stroke saja apa dimsukan selti biar merasakan yg seperti Jessika.',
#   0],
#  ['2024-01-29T18:32:54Z',
#   '@putugangga-gb4zm',
#   'Ini kasus di paksakan karena banyak oknum  tergiur',
#   0],
#  ['2024-01-29T16:14:36Z',
#   '@MyTube_Channels',
#   'Roy suryo asal ngomong doang, ahli ga jels',
#   0],
#  ['2024-01-29T13:15:05Z',
#   '@Riski-je6ti',
#   'Roy Suryo kayak hebat spendiritspi perna dihukum <a href="https://www.youtube.com/watch?v=alOOanmcVVc&amp;t=623">10:23</a> kalo Suryo merasa hebatkesumsel aja biarygg saya Pisa kan nyawa ROI suryo',
#   0],
#  ['2024-01-29T11:53:23Z', '@paesonadian1396', 'Urutan Vidionya GHONDERUWO', 0],
#  ['2024-01-29T11:45:56Z', '@paesonadian1396', 'Sesuwaikan mukanya', 0],
#  ['2024-01-29T04:31:23Z',
#   '@user-cr1ct6zh7w',
#   'yg mereka sasa kasus ini pastinya punya anak dan cucu itu akan tanggung jawab nanti pasti kita percaya itu',
#   0],
#  ['2024-01-29T03:33:46Z',
#   '@koytamadiunkota1227',
#   'Sidang harus di ulang kembali. Tidak ada hal yg tidak mungkin,(orang minta grasi itu,tidak bisa dipaksa ngaku bersalah untuk minta grasi.)',
#   0],
#  ['2024-01-29T03:09:53Z',
#   '@koytamadiunkota1227',
#   'Yg terlibat kasus jesica(polisi hakim,jaksa)harus di usut kasus ini yg seberat beratnya, karena ini mencoreng hukum di indonesia,..sampai di filmkan',
#   0],
#  ['2024-01-28T17:11:20Z',
#   '@kusyantoyantoyanto4805',
#   'Saya orang desa orang awam  pasti bedampak karma kan menimpa siapa saja kl memang jesica tidak melakukan kejahatan atau pembunuhan',
#   0],
#  ['2024-01-28T13:32:45Z',
#   '@edwardsimanjuntak-ei3kv',
#   'Kwalitas hukum dipaparkan progesional...menunjukkan urutan peristiwa sebagai fakta sinar matahari terang bahwa semua dapat melihat dan teryakikan benar dan realita...',
#   0],
#  ['2024-01-28T13:28:30Z', '@VivioPart2-jv8fj', '(+_+)', 0],
#  ['2024-01-28T12:03:04Z', '@omalex2080', 'Mimpiiiiii', 0],
#  ['2024-01-28T05:15:50Z',
#   '@user-hu3sz1li6h',
#   'Sangat benar, bukti membenarkan bahwa itu tangan jesika, yg mana menerangkan bahwa itu jesika..',
#   0],
#  ['2024-01-28T02:50:35Z',
#   '@yogiyogiaboy5921',
#   'Si Roy Suryo tuh yg harus d penjara dia pembohong',
#   0],
#  ['2024-01-27T10:47:37Z',
#   '@user-xo7td6bb9l',
#   'roy silet sendiri sakit gak???<br>coba kasus ini terjadi di keluarga anda.<br>jgnlah gadai kan hati nuranimu  hny demi sesuatu yg tak seberapa nilainya',
#   0],
#  ['2024-01-27T04:38:01Z',
#   '@sigembul1',
#   'Oknum2 yang melek hukum diduga sebagai PELANGGAR HUKUM yang sebenarnya, mereka layak mendapatkan hadiah VONIS HUKUMAN MATI......!!!',
#   0],
#  ['2024-01-27T04:20:45Z',
#   '@sigembul1',
#   'Oknum2 yang melek hukum diduga sebagai PELANGGAR HUKUM yang sebenarnya, mereka layak mendapatkan hadiah VONIS HUKUMAN MATI......!!!😢😢',
#   0],
#  ['2024-01-27T00:44:35Z',
#   '@user-fm6ok6xk4s',
#   'Polri telah melakukan penindakan penyidikan terhadap orang maupun benda yg ada hubungannya dengan kematin korban Mirna di 6 Jan 2016 lalu. Penindakan penyidikan  seperti Pemeriksaan Tkp, Pemanggilan, Penangkapan, penahanan, Penggeledahan, Penyitaan, Pemeriksaan, Penyelesaian berkas perkara, Penyerahan berkas perkara. Setelah kasusnya dinyatakan lengkap maka selanjutnya dilakukan penyerahan tersangka dan barang bukti. Ini oleh Polri dianggap kasus yg ditangani sudah dikatakan selesai.',
#   0],
#  ['2024-01-26T21:42:01Z',
#   '@datinpatraaprillia5886',
#   'Bapa Mirna harus disiasat hingga tuntas,jangan - jangan ada udang dibalik batu,atas kematian Mirna',
#   0],
#  ['2024-01-26T09:59:22Z',
#   '@alextra5398',
#   'Otto hasibuan ..<br>Bravo ....tuhan serta karya mu ...amin',
#   0],
#  ['2024-01-26T09:58:07Z',
#   '@alextra5398',
#   'Jadi cvart nya sudah TDK original ....lagi 😊',
#   0],
#  ['2024-01-26T03:36:37Z',
#   '@YackNggikulaya-qn2fw',
#   'Emas di timbun berabad2 kemurniannya tetap seutuhnya, <br>Kebenar yg sejati tak akan luntur walaupun di rekayasa',
#   0],
#  ['2024-01-25T07:51:44Z',
#   '@user-iu1lp4ek1o',
#   'Dengar itu roi surio biar tdk ngawur memberi jawaban yg tdk dpt di mengerti oleh nizen.',
#   0],
#  ['2024-01-25T00:55:41Z', '@gunawanraharjanto8793', 'Dibuka lagi aja', 0],
#  ['2024-01-24T11:57:26Z',
#   '@julmansyah9525',
#   'Roysuryo gaya saja tapi tidak akhli',
#   0],
#  ['2024-01-24T05:45:37Z', '@jambualas2199', 'Ahli panci', 0],
#  ['2024-01-24T05:45:18Z',
#   '@jambualas2199',
#   'Ini roy suryo perlu di seret  dia juga terlibat',
#   0],
#  ['2024-01-22T16:40:44Z',
#   '@user-zx1xt6vk3n',
#   'Saya berharap dan berdoa semoga apa yang di harapkan pak otto dan Jesicca benar benar terjadi.... teruskan perjuangan bapak... saya ingin melihat akankah hukum di negeri ini bisa menjadi adil',
#   0],
#  ['2024-01-21T13:39:52Z', '@Arnawa-zj8xe', 'Apa  pengadiilan masih adiĺ', 0],
#  ['2024-01-21T09:55:34Z',
#   '@hengkydjoefri1269',
#   'Jangan masyarakat yg tdk bersalah ko dihukum dan dipenjarakan.seharusnya.oknumnya juga dipenjarakan  spy dia harus merasakan juga.ap yg dia rasakan seperti yg dihukum kpd masyarakat.yg tak berdosa',
#   0],
#  ['2024-01-20T22:32:47Z',
#   '@matahariterbit1643',
#   'Kejahatan prasangka terhadap Jasica Wongso sungguh sangat prihatin, orang mati sehabis minum kopi di campur susu coklat dan roti keju sudah sering terjadi di Indonesia, karena susu coklat dan roti keju banyak mengandung pengawet kimia,bagi orang yang tidak tahan akan bahan pengawet kimia mereka mati sesak nafas, hal tersebut sudah sering terjadi di Indonesia, orang mati banyak sebab nya, kebetulan kesialan menimpak jasica Wongso,',
#   0],
#  ['2024-01-17T04:20:38Z',
#   '@muhammadronaldsiagian9864',
#   'Sok merasa ahli kok ngak malu iya org ini bisa ngomong di publik',
#   0],
#  ['2024-01-16T18:52:43Z',
#   '@user-zs1uz5mm9f',
#   'Klw jesica tidak membunuh mirna, alangkah berdosanya hakim yang memvonis jesica 20 tahun.',
#   0],
#  ['2024-01-16T14:14:25Z',
#   '@elahhayati8752',
#   'Terus usut cari sampai tuntas siapa dalang pembunuhan mirna salihin dan siapa2 yg teribat.',
#   0],
#  ['2024-01-15T04:54:32Z',
#   '@user-tf8kc8gi1n',
#   'Hadeh suryo mau apa km itu<br>Km itu gk penting d kasus jesika ngapain km sok komentar dasar tukang panci yo suryo',
#   0],
#  ['2024-01-14T06:51:25Z',
#   '@taufikboeng5367',
#   'Inisih bukan solusi tapi menyesatkan nama aja pakai prof tapi gak ada yg berpikir normal apalagi Roy suryo😂',
#   0],
#  ['2024-01-13T14:42:59Z',
#   '@hasnariasilaen1118',
#   'Haduhhh.... Tolong di percepat lah pengadilan ini...kasihan Jesika lho..! Kita dari masyarakat desa saja bisa mengetahui tidak benar bahwa Jesika melakukan kejahatan yang dituduhkan. Mengapa para pejabat pengadilan sangat payahhh membuat keputusan mana yang benar ?? <br>Semangat bagi para pejabat pembela keadilan, ungkap kan dengan batas waktu lah pak! Apakah sampai habis tahun 2024 tak selesai selesai masalah ini ya????',
#   0],
#  ['2024-01-13T12:06:36Z',
#   '@EngkosKuswara-jd2nc',
#   'Prof Kiki bahasanya ko seperti orang udik/orang Dusun!!',
#   0],
#  ['2024-01-12T17:09:02Z', '@user-ds1wl9hv7f', 'roy masi di percaya', 0],
#  ['2024-01-12T14:14:34Z',
#   '@amrizainal3935',
#   'Mana bisa kita menghormati keputusan hakim yang Double Standard dan termasuk sisontoloyo Surio',
#   0],
#  ['2024-01-12T07:53:39Z',
#   '@jangrisman2764',
#   'Siap siap aja kamu.kamu tukang pitnah..ahli sesat.masa tas pulak di permasaalahan<br>Itu tergantung org nya.narok  tas nya.kamu ini   tukang pitnah.karma.pasti datang dg kamu ahli sesat.tu lawan bang resmon klu kamu benar.sehat selalu pak oto dan doktor jaya.moga dalam lindungan',
#   0],
#  ['2024-01-11T13:13:25Z', '@IsmatulIzza-oj3tg', '🎉🎉🎉', 1],
#  ['2024-01-11T12:53:05Z',
#   '@IsmatulIzza-oj3tg',
#   'Para penegak hukum udah melegang .udah dpt pangkat',
#   0],
#  ['2024-01-10T13:42:11Z',
#   '@johanessutanto586',
#   'Ya jelas jika orang ragu. Roy bukan ahli telematika. Dia cuma pandai cuap² doang.',
#   0],
#  ['2024-01-09T18:04:15Z',
#   '@user-ku4br3jj2r',
#   'Sampai Kapanpun Roy Suryo Adalah Menpora Panci Si Makhluk Penyesat.!!!!',
#   0],
#  ['2024-01-09T12:17:48Z',
#   '@AMLY_Channel',
#   'Kok sepi nih..apakah terhenti tanpa kesan?',
#   0],
#  ['2024-01-08T07:33:12Z',
#   '@rizaldypahlawan2454',
#   'Psti ketakutan bnget tu pelakunya semenjak kasus ini mau diungkp lgi',
#   0],
#  ['2024-01-07T14:13:45Z', '@user-ib5pb4jn8o', '😢😢 bebaskan jesika ❤❤❤❤', 0],
#  ['2024-01-07T14:00:19Z',
#   '@user-ws9ub9zm7k',
#   'Itu sepertinya tangan mengambil sesuatu',
#   0],
#  ['2024-01-06T23:13:05Z', '@bolonuye7838', 'Roy suryo mulut dusta', 0],
#  ['2024-01-06T06:54:04Z',
#   '@nurlaila5427',
#   'Oh itu bgs bgt emag benar harus di buka lg',
#   0],
#  ['2024-01-06T06:50:42Z',
#   '@nurlaila5427',
#   'Tutaskan ke adilan baru mantak',
#   0],
#  ['2024-01-06T06:43:14Z',
#   '@PotensiIDofficial',
#   'Alih alih seperti kasus subang pembunuhan ibu dan anak😅 ternyata pembunuhnya ayahnya sendiri motifnya adalah uang dan ironinya ingin mengkambing hitamkan orang lain parah',
#   0],
#  ['2024-01-06T03:07:56Z',
#   '@user-ux1rg3rz4x',
#   'Sekarang gini lah kalau ayah nya Mirna bersikeras Jesika pembunuh Mirna knp pas baru meninggal ayah nya gk mau di otopsi??',
#   0],
#  ['2024-01-05T16:52:38Z',
#   '@sitisalmah7583',
#   'Sebagainya sengaja di ada adakan',
#   0],
#  ['2024-01-05T14:49:01Z',
#   '@sitisam1191',
#   'Saya kok muak denger kata2 pak edi seperti memojokkan gitu',
#   0],
#  ['2024-01-04T19:51:40Z',
#   '@darmagede3181',
#   'Gimana kompolnas bisa tdk tahu dan mengabaikan prosedur transfer dari DVR??? Aneh ya?',
#   0],
#  ['2024-01-04T13:54:22Z',
#   '@AlexanderKristin-bi6qy',
#   'Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica Bebaskan Jessica,,,',
#   0],
#  ['2024-01-04T12:41:27Z',
#   '@yennyrosa1913',
#   'menganalisis jgn pakai kacamata kuda ya...🙃🤣',
#   0],
#  ['2024-01-04T09:22:30Z',
#   '@orange8172',
#   'Maklumnjugalah jikalu satu kasus di Istimewakan di Mahkamah maka semua harus kasus harus ikutvserta karena Pengadilan ngak ad yangbdi Istimewakan Ya SemuaNya😮. Makayang adilin juga Manusia. Yangdi adilin juga Manusia. Yangada hanya Manusiawi. Adasalah apapun mihon maaflah sebesar besarnya',
#   0],
#  ['2024-01-04T09:16:25Z',
#   '@orange8172',
#   'Begini ajalah aku ada teman nih akrab sekali dan niatnya sudah mau bunuh aku ya karena benci mungkin karena apa ya karena esmisikan. Apayangdi lakukan lakukan senfiri atau sewa pembunuh bayaranjiklaau aku sudah klap ya aku sewa pembunuhlah😮😮😮 kenaoa jikalau aku pasti separoh paroh mau bunuh ngak teg ya ngak bajalan matikkk😮😮😮. Sewapembunuh bayar pasti matikk katanya pembunuhhh😮😮😮',
#   0],
#  ['2024-01-04T09:12:08Z',
#   '@orange8172',
#   'Yang paling ngak jelas ya cctvnya kabur ngak layak jadi bukti<br>Jikalau si Jesicca melakukan umpamannya cctv ngak becus jadi bukti. Kaburtt😂😂😂',
#   0],
#  ['2024-01-04T09:09:29Z',
#   '@orange8172',
#   'Hali ada 2 yang Merah Putih sama warna Orange😂😂😂. Jangansalah Kau😮😮😮. YangOrange di sini aja ngak kemana manaaWak😮😮',
#   0],
#  ['2024-01-04T09:07:30Z',
#   '@orange8172',
#   'Ku keker pulak nanti muka kau dari kamera jalanan 35zoom😮😮',
#   0],
#  ['2024-01-04T09:04:43Z',
#   '@orange8172',
#   'Pakar Ular Sendok ini lagik kenapa dari dulu ngak ngomonggg😮😮😮. Ngimonglahdulukkksendok Kau ular lagik yaa jangan masuk rumah aku yaaa. Akuusir lawan aku. Pikpik pokkk😮😮😮😮. Biarkapokkk😮😮',
#   0],
#  ['2024-01-04T09:03:07Z',
#   '@orange8172',
#   'Akan tetapi jikalau si Jesicca yang salah Negara ngak bakalan hancur jugak😮😮😮 iyakann. Kemungkinannyakan ada siapa beraninjamin 100 persen😮😮',
#   0],
#  ['2024-01-04T09:01:20Z',
#   '@orange8172',
#   'Sebenarnya kan gampang aja jiklau mau dapat Grasi Presidentkan. Ngakusalahlah😮😮😮😮 langsung cap nih ampunkan keluar. Tapimau buat film ya silakannn😂😂😂😂. Manau bela badan atau gensi Nak😮😮',
#   0],
#  ['2024-01-04T08:13:38Z',
#   '@user-np5ey4up6o',
#   'Gereget gua liat dua orang ini',
#   0],
#  ['2024-01-03T19:37:37Z',
#   '@aimanwicaksono3521',
#   'Usut tuntas setuntas tuntasnya...',
#   0],
#  ['2024-01-03T05:53:05Z',
#   '@user-xi2lf3hi8r',
#   'Kasus kematian Mirna di Rekayasa agar salah satu syarat mendapatkan uang Asuransi dan di bagi2 bersama2 😂😂😂😂😂😂',
#   0],
#  ['2024-01-03T04:31:21Z',
#   '@henryhx9889',
#   'Ya si RS tukang bohong nih. Jgn percaya RS dia bukan ahli tapi cenayang.',
#   0],
#  ['2024-01-02T17:43:23Z',
#   '@harapansimbolon6240',
#   'Mantan menteri seperti ini malu  Roy suro. Anda adalah sampah bagi sy.',
#   0],
#  ['2024-01-02T13:53:42Z',
#   '@user-bm6dl6tf2x',
#   'Wah km suryo km itu bohong soalnja km dapat uang dari edi cacaing makanja km sukak bohong',
#   0],
#  ['2024-01-01T20:43:07Z',
#   '@ArifNugroho-hc2xi',
#   'Untuk acara2 seperti ini dan podcas2 gak usahlah menghadirkan roy suryo',
#   0],
#  ['2024-01-01T20:42:33Z',
#   '@ArifNugroho-hc2xi',
#   'Roy suryo ini koq aneh ya. Menurut saya gak jelas ini',
#   0],
#  ['2024-01-01T20:39:02Z', '@ArifNugroho-hc2xi', 'Roy suryo lagi hadedeh..', 0],
#  ['2024-01-01T20:36:44Z',
#   '@fanymarthavia1714',
#   'Semoga Dengan Membuka Ulang kasus ini, tertangkap Pula Pelaku sesungguh nya. Justice For Jessica.',
#   0],
#  ['2024-01-01T17:44:31Z',
#   '@babyzaill7952',
#   'masalah nya citra sambo/kepolisian di indonesia 80% kebanyakan rusak dan gk becus',
#   0],
#  ['2024-01-01T14:17:29Z',
#   '@abdulrahhim6446',
#   'Roy suryo kok ada di situ, wkwk😂😂',
#   0],
#  ['2024-01-01T13:01:35Z',
#   '@syamsulibrahim4542',
#   'JUSTICE FOR YSICA PEMBUNUH ITU , YG SKAN TERBUKA KEBODOHAN MEREKA SEMUA , YG MAU MEMUTAR BALIKKAN FAKTA , KARENA GEROMBOLAN INI MAU JADI PAHLAWSN TSPI SAYANG NYA MEREK SEMUA NYA BANGUN NYA KESIANGAN , ALIAS SEMUA MEREKA PAHLAWAN KESIANGAN !!!!!',
#   0],
#  ['2024-01-01T06:52:48Z',
#   '@jimmyt6962',
#   'Roy jgn cerita masalah lain donx<br>Seolah2 roy pinter ,ini hari mau <br>Menuntaskan ctcv benar tidKnya',
#   0],
#  ['2024-01-01T06:19:38Z',
#   '@RamliMonoarfa-pl4lz',
#   'Bagimana cara pemerintah memperbaiki hukum di indonesia yg sudah sesat di biarkan begitu saja karna ini  nyata menghukum orang TDK bersalah sudah 7 thn',
#   0],
#  ['2024-01-01T05:33:30Z',
#   '@RamliMonoarfa-pl4lz',
#   'Suryo dia minum racun diperiksa TDK ada racun di tubuh kerban  kau yg',
#   0],
#  ['2024-01-01T05:25:24Z', '@RamliMonoarfa-pl4lz', 'Tanganya ada orangnya', 0],
#  ['2024-01-01T05:18:13Z',
#   '@RamliMonoarfa-pl4lz',
#   'Ini tangannya Mak lampir',
#   0],
#  ['2024-01-01T04:50:45Z',
#   '@hanhanong8495',
#   'Kasus Jesica bnyk kejanggalan.<br>Kenapa di tubuh jenazah tidak ada ciri keracunan sianida, tetapi di gelas kopi ada 7400mg sianida sedangkan sianida menguap di 26derajat (cepat menguap).<br>Pemikiran sy adalah kuncinya autopsi, dan kenapa dilarang autopsi untuk mengungkap kebenaran? <br>Saran, seharusnya tidak ada autopsi berarti tidak ada bukti penyebab kematian berarti juga tidak boleh ada tersangka.',
#   0],
#  ['2023-12-31T19:04:02Z',
#   '@JamalludinTuanboi-hk7it',
#   'Di saat itu Ayah mirna ada di cafe olifier itu.',
#   0],
#  ['2023-12-31T18:55:47Z',
#   '@JamalludinTuanboi-hk7it',
#   'Di layar hp,,tangan kiri bisa jadi tangan kanan,,kalau pandangan di tv itu asal tangan kanan.',
#   0],
#  ['2023-12-31T13:12:02Z',
#   '@winidewianggriani6388',
#   'Tegakkan keadilan, Allah maha adil',
#   0],
#  ['2023-12-31T10:58:29Z',
#   '@user-kq3dk3hh1o',
#   'Pak hakim yg memponis jesika 20 tahun, akan di minta pertanggung jawaban oleh Allah swt.',
#   0],
#  ['2023-12-31T06:11:52Z',
#   '@piusbejo5498',
#   'Molai terungkap kasus kopi sianida <br>Mungkin jesika adalah korban sebelum Richad elieser dalam kasus josua😢😢😢😢',
#   0],
#  ['2023-12-31T04:44:26Z',
#   '@hudriansyahhudri8314',
#   'Sy setuju kasus Jesika dibuka kmbali',
#   0],
#  ['2023-12-31T01:43:01Z',
#   '@user-gm2jg8ry8y',
#   'Kenapa begitu bodoh sekali polis dn peguam,sehingga menjadi org bodoh dn bebal untuk menangani kes ini',
#   0],
#  ['2023-12-31T01:14:51Z',
#   '@Adiwiguna-tz9up',
#   'Tolong media Si Roy Suryo jgn diundang pendapatnya ga bermutu. Perlu belajar lagi',
#   0],
#  ['2023-12-30T17:08:23Z',
#   '@gpallawa20',
#   'APA CUMA GUA YANG KEPIKIRAN KALO KOPI SIANIDA ITU DI REKAYASA OLEH PIHAK KELUARGA ALMARHUMA MIRNA DI KARENAKAN  KELUARGA ALMARHUMA MENOLAK DI OTOPSI JASAD DARI MIRNA CUMA PENGAMBILAN SAMPEL DARI LAMBUNG MIRNA DAN HAKIM MEMAKAI BUKTI YANG TAK LANGSUNG SEPERTI PEMBUKTIAN YANG DI AJUKAN TIDAK BERSIFAT FISIK MELAINKAN YANG DI PEROLEH SEBAGAI KESIMPULAN DARI PERISTIWA YANG TERJADI. INTI NYA BEGINI DEH TIDAK ADA SAKSI MATA YANG MELIHAT JESICCA MENUANGKAN SIANIDA DI GELAS KOPI MEREKA CUMA MENDUGA&quot; KALO JESICA ITU PELAKU NYA. FAKTA NYA CAIRAN LAMBUNG YANG DI AMBIL DI DALAM TUBUH  SETELAH MIRNA MATI ADALAH NEGATIF SIANIDA TERUS TUBUH BAGIAN DARI MIRNA TIDAK ADA BERCAK MERAH MELAINKAN WARNA BIRU JIKA KERACUNAN SIANIDA ITU WARNA NYA MERAH BUKAN BIRU TENTANG SIANIDA SOAL NYA SUDAH DI BUKTIKAN BEBERAPA TAHUN YANG LALU ADANYA HASIL DARI PEMERIKSAAN DOKTER.',
#   0],
#  ['2023-12-30T14:33:11Z', '@NSJ_91', 'Buka kembali kasus Jessica', 0],
#  ['2023-12-30T13:18:53Z',
#   '@betrinsengko6333',
#   'Pak Jonson tetap semangat dan berjuang demi keadilan',
#   0],
#  ['2023-12-30T12:31:47Z',
#   '@ricardernandi9859',
#   'Kalau orang lagi menerangkan  pebawa acara jangan nerocos dengerin dulu.',
#   0],
#  ['2023-12-30T08:51:20Z',
#   '@user-fi2nx4bs4q',
#   'Kalau mirna mati setelah minum kopi tp tdk ada bukti keracunan apa berati mirna mati takdir tuhan',
#   0],
#  ['2023-12-30T04:15:21Z',
#   '@ramlisiregarsiregar9570',
#   'usut sampai tuntas bang otto hsb',
#   0],
#  ['2023-12-30T02:20:52Z',
#   '@sabarrianto2832',
#   'Harusnya tangan terlihat penuh  ,itu kelihatan hanya lengan saja ,sebatas punggung keatas baru tdk kelihatan kejanggalan',
#   0],
#  ['2023-12-30T01:13:34Z',
#   '@sarintenwidada7542',
#   'Yang bener ajalah,, ingat gak ada atopsi aja kan?',
#   0],
#  ['2023-12-29T20:20:01Z',
#   '@alkuzrah6836',
#   'Yg pasti allah gak pernah tidur,kalau memang ada kebohongan yg kalian sampai kan,yakin azab allah akan datang buat kalian yg berhati binatanggggggg',
#   0],
#  ['2023-12-29T14:57:22Z',
#   '@user-cd2ff7fh7z',
#   'Dimana cara belajar hukum kalau tak sesuai dgn jalur hukum. Semua dgn dugaan 2 sendiri. Dan pendapat sdr sapa mau korbankan masa dpn nya yg cerah dgn jauh 2 dtg ke indonesia membunuh',
#   0],
#  ['2023-12-29T03:59:55Z',
#   '@elanleki9684',
#   'Mas Roy sama prof Edy sama aja di sogok jadi omonganya menjengkelkan',
#   0],
#  ['2023-12-29T00:47:10Z',
#   '@RahmattAristu-ie6hb',
#   'KANNNN HILANG PERMASALAHAN SIANIDAAA',
#   0],
#  ['2023-12-28T18:07:38Z',
#   '@agussantoso6849',
#   'Roy iru ngaco,,mungkin dpt cuan kok begitu getol bela bpk e mirna',
#   0],
#  ['2023-12-28T12:32:45Z',
#   '@AgusTobaya-kg4ib',
#   'Buka ulang kasus ini..pasti sy jamin jesica tdk bersalah',
#   0],
#  ['2023-12-28T09:04:59Z',
# ...
#   1],
#  ['2023-11-03T22:16:27Z',
#   '@user-nm8sk2nh2h',
#   'Harus di buka kembali ni kasus biar kliatan para pembohong 😊',
#   0],
#  ['2023-11-03T19:58:21Z',
#   '@user-rw2lr3ep8p',
#   'bagai mana kt ngaku klu bukan kt yg melakukannya pak udh bapak ajlh yg mengakukannya udh',
#   0],
#  ['2023-11-03T18:34:04Z',
#   '@indriartosetyobudi4494',
#   'Pinteran abah drpd mas itu',
#   0],
#  ['2023-11-03T16:41:37Z',
#   '@lanzgaming8614',
#   'Udah keliatan lah netizen bukan orang yg bisa mudah d bodohi siapa yang jujur sama siapa yg bohong,miris keadilan hilang cuma gara2 rupiah',
#   0],
#  ['2023-11-03T16:27:26Z',
#   '@akmalwonka6362',
#   'Jesica memang pintar akting..itulah sebabx banyak orang yg tertipu..dan banyak orang hanya cari panggung untuk membela jesica..',
#   0],
#  ['2023-11-03T13:59:17Z',
#   '@annyhorman2749',
#   'justice for Jesika Kumala Wongso',
#   0],
#  ['2023-11-03T13:09:45Z',
#   '@heryherysujoko25',
#   'Yg ngotot cctv itu tanpa rekayasa bang roy. Kelihatan pro bpk mirna dpt bagian kali. Abah ungkap terus kebenaran..',
#   0],
#  ['2023-11-03T12:46:09Z',
#   '@ntn1075',
#   'Dari segi hukum belum selesai kasus Jesica, paham yach Kompolnas. Trims penegak hukum Advokat, Rakyat NKRI  yg baik berani berjuang membela keadilan, mencari pembunuh Mirna, basmi mafia peradilan.',
#   0],
#  ['2023-11-03T12:28:45Z',
#   '@ntn1075',
#   'Trims penegak hukum Advokat, Rakyat NKRI yg baik berani berjuang membela keadilan, mencari pembunuh Mirna, basmi mafia peradilan. Semoga Allah memberikan Presiden pemberani di hukum agar rakyat sejahtera. Amin.',
#   0],
#  ['2023-11-03T12:09:02Z',
#   '@santipontianak9456',
#   'Itu memang betul nampak  jari tangan menaruh sesuatu',
#   0],
#  ['2023-11-03T10:44:03Z',
#   '@fery1441',
#   'Dengar tu yg meragukan bapak djaja.bapak djaja mengarjar samapi s3.sehat selalu bapak djaja',
#   0],
#  ['2023-11-03T10:17:38Z',
#   '@fery1441',
#   'Kenapa si suryo ini gak disuruh ngomg.ngomg terus😂😂😂😂apa dia mulai panik ya',
#   0],
#  ['2023-11-03T09:58:58Z',
#   '@fery1441',
#   'Tv one jgn undang sukro soalnya pendapatnya kurang bisa dipercaya.orang jelas2 muka yg ada tangan itu gak kelihatan',
#   0],
#  ['2023-11-03T07:33:12Z',
#   '@wiwikwardani6622',
#   'Jelas terlihat mana yang benar2 pintar dan mana yang berlagak pintar',
#   0],
#  ['2023-11-03T07:15:28Z',
#   '@hendriyanto-kj2qs',
#   'tuntaskan keadilan gimanasih kerjaanya nggakk beresss.....',
#   0],
#  ['2023-11-03T06:21:42Z',
#   '@rosywiguna1014',
#   'sy yakin jsika pasti tidak bersalah',
#   0],
#  ['2023-11-03T05:54:38Z', '@ramses7912', 'Justice for Jessica...', 0],
#  ['2023-11-03T04:50:22Z',
#   '@sendukelisa9024',
#   'Tangan kelihatan, badannya hantu😅',
#   0],
#  ['2023-11-03T03:46:20Z',
#   '@amranrahakbauw3649',
#   'Ingat FS sudah Terima bagian dari perbuatan, yang lain tunggu waktu Tuhan untuk menerima hadia dari perbuatan atas kasus Jesica.',
#   0],
#  ['2023-11-03T02:28:54Z',
#   '@DI-dx5ho',
#   'Inilah kalo pilih pimpinan dari pedihnya perjuangan, banyak petinggi2 yg ga bener. Dampaknya hukum juga amburadul semua bisa di suap dengan uang. Semua dijadikan bisnis oligarki. Ingat gaes kalo pilih presiden lihat juga  dibelakangnya ada siapa. Itu pengaruh penting. Kalo mau negara makin bobrok pilih lagi junjungannya merah.',
#   0],
#  ['2023-11-03T01:39:55Z', '@normanzainal1347', 'AYAH MINAR KUAT BOHONG.', 0],
#  ['2023-11-03T00:47:38Z', '@pranoto-89aja', 'Tegak kn keadilan', 0],
#  ['2023-11-02T20:34:16Z',
#   '@robbyeverson8193',
#   'Itu si Roy udah kembalikan panci dan alat2 dapur gak yahhh... maksudnya si Roy Konoha... 😊',
#   0],
#  ['2023-11-02T20:16:58Z',
#   '@jagadiraga7814',
#   'Itulah seorang yg gilah kekuwasaan  semua karena uwang .  <br>  DUNIA INI PENU PANGUNG SANWARAH <br>AGAMA DI BUAT INDOSTRI UWANG . INGAT .sampai tertutu motone',
#   0],
#  ['2023-11-02T19:55:18Z',
#   '@rizkyrivalhamid3324',
#   'Saya ingin kasus ini dibuka kembali utk kebaikkan hukum.. agar kedepannya lbh baik lagi',
#   2],
#  ['2023-11-02T19:36:12Z',
#   '@queensilver10queen12',
#   'Cuma gerakan tangan otopsi kagak. Main hukum aja',
#   0],
#  ['2023-11-02T19:31:31Z',
#   '@queensilver10queen12',
#   'Yang kami mau .  Bukti . Mana .. jesika masukan sianida di kopi..paham gak.. ni 2 orang...bukan gerakan tangan',
#   0],
#  ['2023-11-02T19:29:02Z',
#   '@queensilver10queen12',
#   'Enak aja kau pak.. tangan gitu jadikan tersangka coba ke dirimu...',
#   0],
#  ['2023-11-02T19:25:23Z', '@queensilver10queen12', 'Kumis mu potong aja', 0],
#  ['2023-11-02T19:22:09Z',
#   '@user-ic2oe7po3q',
#   'Lu begok... kalau kasih bukti vidio tuh di lihatkan/di perjelas sama mukanya.. lah kalau vidio cuma stengah badan mana bisa si jadikan bukti.. bukti tuh harus jelas dan detail',
#   0],
#  ['2023-11-02T19:21:32Z',
#   '@sayuransegar1809',
#   'Padahal dulu ga pernah disebut, tito karnavian itu.<br><br>Ferdi sambo, krisna murti',
#   0],
#  ['2023-11-02T19:12:29Z',
#   '@queensilver10queen12',
#   'Wajah nya aja tidak keliatan tangan nya aja gtu... menaruh ke gelas juga tidak.  Bukti poex itu',
#   0],
#  ['2023-11-02T19:10:34Z', '@queensilver10queen12', 'Editan itu....', 0],
#  ['2023-11-02T19:06:08Z',
#   '@queensilver10queen12',
#   'Masalah nya tidak di terima ni kasus bukti tidak ada. <br>Lalu hanya logika saja ..insting hakim....bukti nyata kami mau',
#   0],
#  ['2023-11-02T19:04:11Z', '@queensilver10queen12', 'Buka lagi kasus nya', 0],
#  ['2023-11-02T18:20:06Z',
#   '@catrinesharon5618',
#   'Up....terus jgn kasih kendor',
#   0],
#  ['2023-11-02T18:07:07Z', '@user-rp1xb2lt2o', 'Mantap bang oto', 0],
#  ['2023-11-02T18:06:03Z', '@user-rp1xb2lt2o', 'Mantap bang oto', 0],
#  ['2023-11-02T17:47:15Z',
#   '@user-rp1xb2lt2o',
#   'Benar sekali tida kelihatan sama sekali klu jesika menaruh racun',
#   0],
#  ['2023-11-02T17:45:17Z',
#   '@user-rp1xb2lt2o',
#   'Bedah kembali klu bisa, biar ketahuan siapa yang sebenernya bersalah. Karna kasihan klu jesika klu dia tida bersalah',
#   0],
#  ['2023-11-02T17:21:10Z',
#   '@user-rp1xb2lt2o',
#   'Semoga sehat slalu untuk jesica',
#   0],
#  ['2023-11-02T17:09:05Z',
#   '@mariorio5946',
#   'Kasus di buka.. Biar lebi jelas... <br>Jgn asal asal menudu jesika tanpa gak ada bukti',
#   0],
#  ['2023-11-02T17:03:22Z',
#   '@Ghebot73-nz7fd',
#   'Harus di buka kembali demi keadilan, kasihan Jesica',
#   0],
#  ['2023-11-02T15:45:32Z',
#   '@turiyah5993',
#   'Semoga ajh semua bisa terungkap mana yang salah mana yang bener',
#   0],
#  ['2023-11-02T15:13:58Z',
#   '@AgusAgusprio',
#   'Muak bngt liat Roy Suryo kakehan ngoceh ora jelas',
#   0],
#  ['2023-11-02T15:13:23Z',
#   '@AgusAgusprio',
#   'Roy sya jg mengatakan asli,tp asli kl km tukang korupsi',
#   0],
#  ['2023-11-02T15:11:53Z',
#   '@AgusAgusprio',
#   'Roy Suryo kan tukang korupsi ko dipercya,turoy diduapsm Edi bpknya Mirna,mknya mulute lancar,inget hukum karma Roy suryo',
#   0],
#  ['2023-11-02T15:08:39Z',
#   '@user-mo9vw4xl2w',
#   'Negri jesica dan josua.,semoga anak negri memberantas oknum2 yg sangat jahat.',
#   0],
#  ['2023-11-02T13:52:51Z',
#   '@ketutkusnadi6372',
#   'Tolong dan tolong........... Kasus ini hatus ditinjau ulang..... Demi nama bangsa simata rakyatnya...... Tolong...............',
#   0],
#  ['2023-11-02T13:26:38Z',
#   '@gatolocogrub5357',
#   'Saya suka dengan abi. Tidak memihak. Kalo bapak roy kelihatanya ada memihak',
#   0],
#  ['2023-11-02T13:16:06Z',
#   '@user-ny2nu5bc7j',
#   'Kalau jesika meracuni kopi mirna pasti jesika kelihatan menuang racun darisesuatu.wadah plastik atau botol..karena itu ditempat yg ramai dan ada cctv..ini sangat janggal',
#   0],
#  ['2023-11-02T12:59:55Z',
#   '@sarmuji1250',
#   'Roy suryo balikin panci sendok dan alat dapur milik negara',
#   0],
#  ['2023-11-02T11:46:24Z',
#   '@lmuhdar339',
#   'Harus di buka lagi kasus Jessica ini...supaya masyarakat tau cara kerja kepolisian kejaksaan dan hakim di Indonesia yg sudah mencoreng wajah hukum Indonesia di mata dunia.',
#   33],
#  ['2023-12-02T17:24:54Z', '@TofikDj-fw5tf', 'BENAR SEKALI BRO.', 0],
#  ['2024-03-09T16:19:04Z',
#   '@user-er5ks6rx4n',
#   'SOPnya lari semua ...gk jelas ya amburadul. Dan semaunya ..gk ikuti aturan ...rusak sistem peradila kita ....',
#   0],
#  ['2023-11-02T11:37:05Z',
#   '@syahrulinoval2937',
#   'ORANG-ORANG PINTER KE BLINGER TAMPIL<br>BANYAK BACOT<br>GUE YAKIN JESIKA 1000% BUKAN PELAKU',
#   1],
#  ['2023-11-02T11:33:50Z',
#   '@user-hk3kr6ps3d',
#   'Jika ketentuan hukum Indonesia setiap org yang mati harus izin dari keluarga dahulu baru bs ada tindakan autopsi. Maka bagaimana misal terjadi pembunuhan yg dilakukan suami/istri/anak/orang tua. Bisa saja mereka menolak untuk autopsi krna takut donk ketahuan jika dy yg melakukan tindakan tsb.',
#   0],
#  ['2023-11-02T10:20:51Z', '@AdeRahmat-eb7zl', '😅😅😅😅', 1],
#  ['2023-11-02T09:00:20Z',
#   '@kurowawan9936',
#   'Bajunya jg lengan panjang itu Jesica kan lengan pendek suryo',
#   0],
#  ['2023-11-02T08:55:33Z', '@kurowawan9936', 'Dia itu melihat jam suryo', 0],
#  ['2023-11-02T08:54:10Z', '@kurowawan9936', 'Suryo suryo', 0],
#  ['2023-11-02T08:39:25Z', '@user-ll9dv6mh7l', 'Uang uang uang 😅', 0],
#  ['2023-11-02T07:11:08Z',
#   '@eranetijen6045',
#   'Keterangan Pak Roy Suryo lebih layak disampaikan dukun.',
#   0],
#  ['2023-11-02T05:11:59Z',
#   '@howtomakebracelet3388',
#   'Pengadilan biadab 👎👎👎',
#   0],
#  ['2023-11-02T04:54:31Z', '@wendrafiale8116', 'Roy suryo plenga plongo😂', 0],
#  ['2023-11-02T04:52:51Z', '@wendrafiale8116', 'Roy suryo Kacang goreng😅', 0],
#  ['2023-11-02T04:32:36Z', '@taufikboeng5367', 'alah sok pintar', 0],
#  ['2023-11-02T04:24:57Z',
#   '@ijahamir8749',
#   'Dah jgn di percaya omongan mereka pembohong tuh',
#   0],
#  ['2023-11-02T04:20:03Z',
#   '@ijahamir8749',
#   'Seharus ya di ungkap kembali ,yg benar tetap benar ,yg salah tetap salah, jgn hy demi uang semua kalian jaksa dan hakim diam aja nurut aja perintah Orang tua ya ,sementara orang yg bersalah di penjara 20 th ,kalian gak takut apa dgn pembalasan Alam semesta',
#   0],
#  ['2023-11-02T04:19:40Z',
#   '@muhammadguntur791',
#   'Ini adalah kasus keracunan, wajib butuh bukti yang akurat terutama visum et repertum tapi oknum hakim yang bersangkutan berkeyakinan hanya berdasarkan dari apa yang terkandung dalam cctv, tapi tidak dari hasil autopsi apa yang terkandung di dalam tubuh jenazah yang di duga terpapar racun natrium cianad (NaCN) / sianida.<br>Pertanyaannya apakah majelis hakim bersidang untuk membela cctv atau membela hak mirna dan jessica???<br>Hakim koplak!!!<br>Memalukan!!!',
#   0],
#  ['2023-11-02T03:02:59Z',
#   '@apengsniper4995',
#   'roy suryo suruh ngapal lagu pancasila dlu 🤣🤣',
#   0],
#  ['2023-11-02T02:46:54Z',
#   '@greatpeople831',
#   'JIka bpk Mahfud Md berani dan mau membantu menbongkar kasus ini yg sgt janggal dan bnyk rekayasa, pasti nanti sewaktu pilpress ini netizen bnyk yg berterima kasih dgn banyak yg condong memilih bpk dan Ganjar Pranowo... Pasti menang, saya yakin kebenaran akan menang',
#   0],
#  ['2023-11-02T02:20:51Z', '@setyomijan3632', 'Ayo usut balik PK', 0],
#  ['2023-11-02T01:47:36Z', '@trirahayu1986', 'Dasar maling panci 😅😅😅', 0],
#  ['2023-11-02T01:46:43Z',
#   '@AmriJal-zf8yz',
#   'Yg di bilang bg oto itu betul tukjuk kan di piar asli nya asli nya di putar di pengadilan biar rakyat Indonesia tau semua jujur demi bangsa',
#   0],
#  ['2023-11-02T01:33:31Z',
#   '@AmriJal-zf8yz',
#   'Kasus ini pelajaran bagi kita semua untuk jangan memesan apa pun sebelum kerabat atau kawan yg belum datang ke kafe atau rumah makan,tunggu dulu datang baru pesan',
#   0],
#  ['2023-11-02T00:41:42Z',
#   '@antoniussulianto3965',
#   'Bagaimana kalau pengacara top buka komunitas pembela kebenaran......',
#   0],
#  ['2023-11-02T00:40:43Z',
#   '@antoniussulianto3965',
#   'Buka kembali sebagai pelajaran orang-orang yang tidak bertanggung jawab ......',
#   0],
#  ['2023-11-02T00:39:41Z',
#   '@antoniussulianto3965',
#   'Brantas keadilan yang tidak sehat disemua bidang penyakit ini banyak meraja rela......ayooo semua muncul yang pernah punya kasus hukum tidak sehat...',
#   0],
#  ['2023-11-02T00:16:01Z',
#   '@apriliaiueo1',
#   'senyum roy suryo manipulatif banget jiji',
#   0],
#  ['2023-11-01T19:22:54Z',
#   '@user-mc3gw3fs8v',
#   'Masyrakat masih prcaya dgn ahli RY it ya...',
#   0],
#  ['2023-11-01T19:05:03Z',
#   '@tikerpiggy',
#   'disini terlihat banget yaaa mana yg suka bohong segala jurus di tebas haduuhh pak pak ngga takut hukuman Tuhan apa ya? jeblosin org tanpa bukti kuat',
#   0],
#  ['2023-11-01T16:55:23Z',
#   '@amanggepeng4844',
#   'Konoha om keadilan bagi orng yang berduit😂😂',
#   0],
#  ['2023-11-01T16:47:19Z',
#   '@buncono4250',
#   'Smoga Tuhan melindungi jesica  Aamiin......q mendukungmu jess....junjung tinggi kebenaran',
#   0],
#  ['2023-11-01T15:48:01Z',
#   '@Fioren0876',
#   'Secara pribadi sy berpendapat agar kasus ini dibuka lagi. Bukti video saja tdk cukup. Yang paling akurat menurut saya adalah hasil pemeriksaan atas jenazah. Itu fakta yg tdk akan terbantahkan. Video bisa banyak diubah tp hasil pemeriksaan itu tdk akan terbantahkan. Kita akan melihat bagaimana supremasi hukum di Indonesia utk menegakkan kebenaran dan keadilan. Org tdk bersalah bagaimana pun tidak bisa dihukum.',
#   0],
#  ['2023-11-01T14:49:02Z',
#   '@orang_miskin',
#   'Meragukan .....!!!!!!!<br>Mirna GK perlu di otopsi udha jelas di cctv kok ada sanksi nya temannya sedri dia minum kopi meningal... kok ribet amat cari kematian... itu adalah faktanya yg rel gk perlu otopsi... jelas mengal bkarna minum kopi yg ada racunnya. Mau racun apa kek sianida atau rcun tikus, faktanya di lapangan sudah jelas ada saksi nya temen nya Miran sedri. Ada pula cctv yg menguatkann fakta tersebut.... bicara kasus ini harus ada fariablel logikanya..<br>Gw duga ada indikasi 70%pelakunya Jesika sedri mengigat dia sikologis nya ada yg aneh dan apnormal pada manusia umumnya... <br>Punya riwayat pertengkaran dgn kekasih di Singapura Sampai masuk kerana hukum.<br>Pakean yg di pake dia di kafe buang..<br><br>Memesan duluan beberapa waktu yg lama seblum datang nya teman nya ..<br>Lirik sana lirik sini di kafe tersebut...<br>Dan mengatur2 paperbek di cctv.... itu fariablelnya logis yg bisa di ambil kesimpulan...... hargailah hakim yg berfikir dan ahli2 yg SDH bekerja....<br>Dan berfikir lah logis..',
#   0],
#  ['2023-11-01T14:39:06Z', '@AndiAndi-ze4qo', 'Owh ada bapak panci', 1],
#  ['2023-11-01T13:56:24Z',
#   '@user-gd6cm2xu8k',
#   'Aku tuh heran di Indonesia ada masalah sebesar apapun kenapa ROY SURYO selalu berpihak pada yg salah, apa itu sudah pekerjaan dia atau memang dia di ciptakan jadi orang yang tidak pantas di hormati',
#   0],
#  ['2023-11-01T13:45:50Z',
#   '@user-np9no7pe7n',
#   'Seandainya negara tidak melakukan sidang ulang terhadap jessica.<br>Para perangkat perdilan siap siap aja atas karma memenjarakan orang yang tidak bersalah....Tuhan maha adil segala galanya....',
#   0],
#  ['2023-11-01T13:36:11Z',
#   '@edobere1238',
#   'Hukum   kita   ini   apa   lata    elit',
#   0],
#  ['2023-11-01T12:45:18Z',
#   '@user-np9no7pe7n',
#   'Yo...suryo......elu ahli digital apa ahli nebak.....yo......',
#   0],
#  ['2023-11-01T12:35:48Z',
#   '@chalisapermata3965',
#   'Sya mohon kasus ini diungkap sprti sambo',
#   0],
#  ['2023-11-01T12:11:48Z',
#   '@ajiempekok7315',
#   'itu oknum polisi/kompolnas pak Edi H. gak profesional menangani kasus mirna..polisi asal dpet duit juga jalan aja ssuai kepentingan org tsb. aparat hukum dan penegak hukum d indonesia emang amburadul,menjijikan .',
#   0],
#  ['2023-11-01T11:52:41Z',
#   '@haidarkiki1266',
#   'jesica tdk bersalah ,,,,,tdk.ada bukti ,,,',
#   0],
#  ['2023-11-01T11:13:06Z',
#   '@belindayusup5554',
#   'Betul sangat... Mana ada zoom camera cctv  satu sudut terlalu dekat dan tuju satu hala saja..',
#   0],
#  ...]

# %% [markdown]
# #4. Ubah Hasil Crawling ke Dataframe

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#                publishedAt   authorDisplayName  \
# 0     2024-03-27T14:51:00Z  @EkoPrasetyo-vm2my
# 1     2024-03-26T14:57:39Z     @umihjnurra5809
# 2     2024-03-25T10:32:31Z    @Adrian123-uv9js
# 3     2024-03-24T21:18:31Z      @dewabuana9128
# 4     2024-03-24T18:33:56Z    @helmybalweel782
# ...                    ...                 ...
# 9673  2023-10-10T15:47:01Z   @khairarizqya6727
# 9674  2023-10-10T15:56:31Z             @yodlls
# 9675  2023-10-10T16:00:13Z    @sportlovers7773
# 9676  2023-10-10T17:43:35Z   @khairarizqya6727
# 9677  2023-10-10T23:07:59Z             @yodlls
#
#                                             textDisplay  likeCount
# 0     Mo nnya knp krisna murti nya ga di undang jg y...          0
# 1     Ya ungkap kembali keadilan tetep harus di tega...          0
# 2     Butuh berapa lama reaksi racun bekerja pada tu...          0
# 3     Masyarakat ingin kasus jessica diungkap kembal...          0
# 4     Terlanjur bnyak yg akan JATUH jika kebenaran T...          1
# ...                                                 ...        ...
# 9673  terlalu d kejar waktu jd ga puas  denger naras...          0
# 9674       kalo mau jelas nonton podcast aja mba banyak          0
# 9675                   podcastNya Dr. Ricard mntap tuh.          0
# 9676  udh sy tonton semua tp d sini mumpung hadir pe...          0
# 9677  @@khairarizqya6727 ya karna ini acara tv ya wa...          0
#
# [9678 rows x 4 columns]

# %% [markdown]
# #5. Simpan Hasil Crawling ke file CSV

# %%
df.to_csv('youtube-comments.csv', index=False)

# %%
# Input library yang digunakan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Ingin belajar lebih banyak lagi?
#
# Banyak video pembelajaran terkait Machine Learning yang disajikan di channel Youtube http://youtube.com/c/AchmadSolichin. Silahkan berkunjung dan jangan lupa **SUBSCRIBE** untuk membantu pengembangan channel dengan video-video berkualitas lainnya.
#
# ## Terima kasih, selamat belajar!
#
# Notebook ini dibuat oleh: <a href = "http://achmatim.net">Dr. Achmad Solichin</a> dengan acuan dari berbagai sumber:
# 1. https://www.geeksforgeeks.org/how-to-extract-youtube-comments-using-youtube-api-python/
#
# <hr>
# Copyright &copy; 2022 [Achmatim.Net](http://achmatim.net). This notebook and its source code are released under the terms of the CC License.​
